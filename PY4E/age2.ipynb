# %%
# 생일 지남 여부
birth = int(input("생일이 지났습니까? 맞으면 0 아니면 -1 : "))
# 한국 나이 입력
korean_age = int(input("한국 나이 입력 : "))
american_age = korean_age + birth - 1
print("미국 나이 : ", american_age)
# Out:
# 생일이 지났습니까? 맞으면 0 아니면 -1 : -1
# 한국 나이 입력 : 58
# 미국 나이 :  56
