# %%
year = int(input("당신이 태어난 연도를 입력해주세요: "))
birth_tag = int(input("생일이 지났습니까? 맞으면 0, 아니면 -1: "))
kor_age = 2023 - year + 1
if birth_tag == 0:
  us_age = 2023 - year
elif birth_tag == -1:
  us_age = 2023 - year - 1
print("당신의 한국 나이는:", kor_age)
print("당신의 미국 나이는:", us_age)
# Out:
# 당신이 태어난 연도를 입력해주세요: 1966
# 생일이 지났습니까? 맞으면 0, 아니면 -1: -1
# 당신의 한국 나이는: 58
# 당신의 미국 나이는: 56
