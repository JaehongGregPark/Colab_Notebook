# %%
# !pip install selenium
# !apt-get update
# !apt install chromium-chromedriver
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 53.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.2/400.2 kB 35.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.0 MB/s eta 0:00:00
# ...
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [109 kB]
# Get:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease [18.1 kB]
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,005 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,351 kB]
# ...

# %%
import sys
sys.path.insert(0, '/usr/lib/chromium-browser/chromedriver')
from selenium import webdriver

# %%
options = webdriver.ChromeOptions()
options.add_argument('--headless') # 화면 출력 x
options.add_argument('--no-sandbox') # ?
options.add_argument('--disable-dev-shm-usage') # /deb/shm 디렉토리를 사용하지 않음 공유메모리를 담당
wd = webdriver.Chrome('chromedriver', options=options)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-e8bd5d6a8636> in <cell line: 5>()
#       3 options.add_argument('--no-sandbox') # ?
#       4 options.add_argument('--disable-dev-shm-usage') # /deb/shm 디렉토리를 사용하지 않음 공유메모리를 담당
# ----> 5 wd = webdriver.Chrome('chromedriver', options=options)
#
# TypeError: WebDriver.__init__() got multiple values for argument 'options'

# %%
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# chromium-chromedriver is already the newest version (1:85.0.4183.83-0ubuntu2.22.04.1).
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

options = webdriver.ChromeOptions()
options.add_argument('--headless')  # (optional) 화면 표시 안 함
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

# 드라이버 경로 설정 (Chrome인 경우)
driver = webdriver.Chrome('chromedriver', options = options)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-322ebb0463a2> in <cell line: 10>()
#       8
#       9 # 드라이버 경로 설정 (Chrome인 경우)
# ---> 10 driver = webdriver.Chrome('chromedriver', options = options)
#
# TypeError: WebDriver.__init__() got multiple values for argument 'options'

# %%
from selenium import webdriver

# 옵션 설정
options = webdriver.ChromeOptions()

# 필요한 옵션을 추가하세요. 예를 들어:
options.add_argument('--headless')  # Chrome을 헤드리스 모드로 실행

# 드라이버 경로 설정 (만약 Chrome을 사용하는 경우)
driver = webdriver.Chrome(executable_path='chromedriver', options=options)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-e67b8a1d9ada> in <cell line: 10>()
#       8
#       9 # 드라이버 경로 설정 (만약 Chrome을 사용하는 경우)
# ---> 10 driver = webdriver.Chrome(executable_path='chromedriver', options=options)
#
# TypeError: WebDriver.__init__() got an unexpected keyword argument 'executable_path'

# %%
from selenium import webdriver

# Set up options
options = webdriver.ChromeOptions()

# Add your options here, for example:
options.add_argument('--headless')  # Run Chrome in headless mode

# Set the path to the Chromedriver executable
chrome_path = '/path/to/chromedriver'  # Replace with the actual path to your chromedriver executable

# Create the webdriver instance without executable_path
driver = webdriver.Chrome(options=options)

# If you are still facing issues, you can use the service_args parameter:
# driver = webdriver.Chrome(options=options, service_args=["--verbose", "--log-path=/path/to/chromedriver.log"])

# Navigate to a website to test
driver.get("https://www.naver.com")
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# <ipython-input-8-8dd925e969e7> in <cell line: 13>()
#      11
#      12 # Create the webdriver instance without executable_path
# ---> 13 driver = webdriver.Chrome(options=options)
#      14
#      15 # If you are still facing issues, you can use the service_args parameter:
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, options, service, keep_alive)
#      43         options = options if options else Options()
#      44
# ---> 45         super().__init__(
#      46             DesiredCapabilities.CHROME["browserName"],
#      47             "goog",
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chromium/webdriver.py in __init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      54
#      55         try:
# ...
