# %%
import pandas as pd
import numpy as np

df = pd.read_csv(
    '/content/drive/MyDrive/Colab Notebooks/ORANGE데이터분석/healthcare-dataset-stroke-data.csv')
df.head(3)

#원본 데이터프레임 df에서 세개의 연속 변수만 별도로 데이터프레임 df1에 저장
cols = ['age','avg_glucose_level','bmi']
df1 = df[cols]
df1.head(3)
# Out:
#     age  avg_glucose_level   bmi
# 0  67.0             228.69  36.6
# 1  61.0             202.21   NaN
# 2  80.0             105.92  32.5

# %%
df2 = df1.dropna()
df2.describe()
# Out:
#                age  avg_glucose_level          bmi
# count  4909.000000        4909.000000  4909.000000
# mean     42.865374         105.305150    28.893237
# std      22.555115          44.424341     7.854067
# min       0.080000          55.120000    10.300000
# 25%      25.000000          77.070000    23.500000
# 50%      44.000000          91.680000    28.100000
# 75%      60.000000         113.570000    33.100000
# max      82.000000         271.740000    97.600000
